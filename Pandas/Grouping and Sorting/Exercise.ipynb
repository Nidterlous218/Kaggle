# %%
import pandas as pd
reviews = pd.read_csv("winemag-data-130k-v2.csv", index_col = 0)
pd.set_option('display.max_row', 5)
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews_written = reviews.groupby(['taster_twitter_handle']).taster_twitter_handle.count()
reviews_written
# Out:
# taster_twitter_handle
# @AnneInVino        3685
# @JoeCz             5147
#                    ...
# @winewchristina       6
# @worldwineguys     1005
# Name: taster_twitter_handle, Length: 15, dtype: int64

# %%
best_rating_per_price = reviews.groupby('price').points.max()
best_rating_per_price
# Out:
# price
# 4.0       86
# 5.0       87
#           ..
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
price_extremes = reviews.groupby('variety').apply(lambda x: x.price.agg([max, min]))
price_extremes
# Out:
# C:\Users\liewm\AppData\Local\Temp\ipykernel_17448\509336052.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   price_extremes = reviews.groupby('variety').apply(lambda x: x.price.agg([max, min]))
# C:\Users\liewm\AppData\Local\Temp\ipykernel_17448\509336052.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   price_extremes = reviews.groupby('variety').apply(lambda x: x.price.agg([max, min]))
# ...

# %%
sorted_varieties = price_extremes.sort_values(by = ['min', 'max'], ascending = False)
sorted_varieties
# Out:
# price        max    min
# variety
# Ramisco    495.0  495.0
# Terrantez  236.0  236.0
# ...          ...    ...
# Vital        NaN    NaN
# Zelen        NaN    NaN
#
# [707 rows x 2 columns]

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviewer_mean_rating = reviews.groupby('taster_name').points.mean()
reviewer_mean_rating
# Out:
# taster_name
# Alexander Peartree    85.855422
# Anna Lee C. Iijima    88.415629
#                         ...
# Susan Kostrzewa       86.609217
# Virginie Boone        89.213379
# Name: points, Length: 19, dtype: float64

# %%
reviewer_mean_rating.describe()
# Out:
# count    19.000000
# mean     88.233026
#            ...
# 75%      88.975256
# max      90.562551
# Name: points, Length: 8, dtype: float64

# %%
country_variety_counts = reviews.groupby(['country', 'variety']).size()
country_variety_counts.sort_values(ascending = False)
# Out:
# country  variety
# US       Pinot Noir            9885
#          Cabernet Sauvignon    7315
#                                ...
# Mexico   Rosado                   1
# Uruguay  White Blend              1
# Length: 1612, dtype: int64
